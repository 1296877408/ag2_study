# %%
# !pip install autogen
# !pip install ag2[rag]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.3/739.3 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 4.0 MB/s eta 0:00:00
# ...
# ...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.7/808.7 kB 49.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# 挂载 Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 创建一个目录来存放库（假设为 /content/drive/MyDrive/libs）
# !mkdir -p /content/drive/MyDrive/libs

# 将库安装到该目录
# !pip install autogen -t /content/drive/MyDrive/libs
# !pip install ag2[rag] -t /content/drive/MyDrive/libs

# %%
# 添加该目录到系统路径，以便后续使用
import sys
sys.path.append('/content/drive/MyDrive/libs')

# %%
pip index versions docling_core
# Out:
# WARNING: pip index is currently an experimental command. It may be removed/changed in a future release without prior warning.
# docling_core (2.27.0)
# Available versions: 2.27.0, 2.26.4, 2.26.3, 2.26.2, 2.26.1, 2.26.0, 2.25.0, 2.24.1, 2.24.0, 2.23.3, 2.23.2, 2.23.1, 2.23.0, 2.22.0, 2.21.2, 2.21.1, 2.21.0, 2.20.0, 2.19.1, 2.19.0, 2.18.1, 2.18.0, 2.17.2, 2.17.1, 2.17.0, 2.16.1, 2.16.0, 2.15.1, 2.14.0, 2.13.1, 2.12.1, 2.12.0, 2.11.0, 2.10.0, 2.9.0, 2.8.0, 2.7.1, 2.7.0, 2.6.1, 2.5.1, 2.5.0, 2.4.1, 2.4.0, 2.3.2, 2.3.1, 2.3.0, 2.2.3, 2.2.2, 2.2.1, 2.2.0, 2.1.0, 2.0.1, 2.0.0, 1.7.2, 1.7.1, 1.7.0, 1.6.3, 1.6.2, 1.6.1, 1.6.0, 1.5.0, 1.4.1, 1.4.0, 1.3.0, 1.2.0, 1.1.4, 1.1.3, 1.1.2, 1.1.1, 1.1.0, 1.0.0, 0.2.0, 0.0.1

# %%
# !pip install docling_core==2.27.0

# %%
import os

import autogen
from autogen import AfterWorkOption, ConversableAgent, initiate_swarm_chat
from autogen.agents.experimental import DocAgent
os.getcwd()
# Out:
# '/content'

# %%
# !pip show docling_core
# Out:
# Name: docling-core
# Version: 2.27.0
# Summary: A python library to define and validate data types in Docling.
# Home-page: https://github.com/docling-project
# Author: Cesar Berrospi Ramis
# Author-email: ceb@zurich.ibm.com
# License: MIT
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: jsonref, jsonschema, latex2mathml, pandas, pillow, pydantic, pyyaml, tabulate, typer, typing-extensions
# Required-by: docling, docling-ibm-models, docling-parse

# %%
# Load configuration from the OAI_CONFIG_LIST file, requires the api_key to exist in the configuration
# config_list = autogen.config_list_from_json(
#     env_or_file="config.json",
#     file_location="./drive/MyDrive/config",
#     filter_dict={
#         "model": ["gpt-4o-mini"],
#     },
# )
# print(config_list)
# Set the OPENAI_API_KEY from the configuration so that the internal ingestion can use it
os.environ["OPENAI_API_KEY"] = "sk-sTMmF6HjOoQPwBUUCa3aA6C5C7844d189eAb5bAa5bA3CcFc"
os.environ["OPENAI_API_BASE"] = "http://oneapi.waidev.cc/v1"

llm_config = {
    "config_list": [
{
  "model":"gpt-4o-mini",
  "base_url":"http://oneapi.waidev.cc/v1",
  "api_type":"openai",
  "api_key":"sk-sTMmF6HjOoQPwBUUCa3aA6C5C7844d189eAb5bAa5bA3CcFc"
}
],
}

# %%
# !unzip ./drive/MyDrive/dataset/SEC\ Filings\ -\ AAPL,\ XOM,\ JPM.zip -d ./drive/MyDrive/dataset/finacial_dataset
# Out:
# Archive:  ./drive/MyDrive/dataset/SEC Filings - AAPL, XOM, JPM.zip
#    creating: ./drive/MyDrive/dataset/finacial_dataset/SEC Filings - AAPL, XOM, JPM/
#    creating: ./drive/MyDrive/dataset/finacial_dataset/SEC Filings - AAPL, XOM, JPM/Apple/
#   inflating: ./drive/MyDrive/dataset/finacial_dataset/SEC Filings - AAPL, XOM, JPM/.DS_Store
#   inflating: ./drive/MyDrive/dataset/finacial_dataset/__MACOSX/SEC Filings - AAPL, XOM, JPM/._.DS_Store
#    creating: ./drive/MyDrive/dataset/finacial_dataset/SEC Filings - AAPL, XOM, JPM/Exxon Mobil/
#    creating: ./drive/MyDrive/dataset/finacial_dataset/SEC Filings - AAPL, XOM, JPM/JPM Chase/
#    creating: ./drive/MyDrive/dataset/finacial_dataset/SEC Filings - AAPL, XOM, JPM/Apple/10Q/
#    creating: ./drive/MyDrive/dataset/finacial_dataset/SEC Filings - AAPL, XOM, JPM/Apple/10K/
#   inflating: ./drive/MyDrive/dataset/finacial_dataset/SEC Filings - AAPL, XOM, JPM/Apple/.DS_Store
# ...

# %%
# Create a document agent and ask them to ingest the document and answer the question
document_agent = DocAgent(llm_config=llm_config,collection_name="toast_report",)

run_response = document_agent.run(
    message="could you ingest /content/drive/MyDrive/dataset/finacial_dataset/SEC\ Filings\ -\ AAPL,\ XOM,\ JPM/Apple/10K/AAPL_10K_2020.pdf? What does this article describe?",
    max_turns=1,
)
run_response.process()
# Out:
# INFO:autogen.agents.experimental.document_agent.chroma_query_engine:Creating new collection toast_report in the database.
# user (to DocAgent):
#
# could you ingest /content/drive/MyDrive/dataset/finacial_dataset/SEC\ Filings\ -\ AAPL,\ XOM,\ JPM/Apple/10K/AAPL_10K_2020.pdf? What does this article describe?
#
# --------------------------------------------------------------------------------
# _User (to chat_manager):
#
# could you ingest /content/drive/MyDrive/dataset/finacial_dataset/SEC\ Filings\ -\ AAPL,\ XOM,\ JPM/Apple/10K/AAPL_10K_2020.pdf? What does this article describe?
#
# --------------------------------------------------------------------------------
#
# Next speaker: DocumentTriageAgent
#
# DocumentTriageAgent (to chat_manager):
#
# {"ingestions":[{"path_or_url":"/content/drive/MyDrive/dataset/finacial_dataset/SEC Filings - AAPL, XOM, JPM/Apple/10K/AAPL_10K_2020.pdf"}],"queries":[{"query_type":"RAG_QUERY","query":"What does this article describe?"}]}
#
# ...
